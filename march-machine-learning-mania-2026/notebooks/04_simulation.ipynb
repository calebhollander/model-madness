# %% [markdown]
# # Bracket simulation (optional)
#
# Simulate the tournament bracket using predicted P(Team A beats Team B): load slots and seeds, resolve each game (sample or argmax), and optionally write results to `outputs/simulation_results.csv`.

# %%
import sys
sys.path.insert(0, '..')
from src import simulate

# Stubs: load_bracket_slots(), simulate_tournament(prob_fn, slots_df, seeds_df, season), run_simulation()
try:
    simulate.load_bracket_slots()
except (NotImplementedError, Exception):
    print("simulate.load_bracket_slots: load MNCAATourneySlots and seeds.")
try:
    simulate.simulate_tournament(lambda s, a, b: 0.5, None, None, 2025)
except (NotImplementedError, Exception):
    print("simulate_tournament: resolve bracket from prob_fn(season, team_a, team_b).")
